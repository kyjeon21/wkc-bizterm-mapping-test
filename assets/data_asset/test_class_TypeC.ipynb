# %% [markdown]
# ## 1. import libs

# %%
from ibm_watson_studio_lib import access_project_or_space
wslib = access_project_or_space()

# %%
wslib.download_file("gov_map_ver6.py", "gov_map_ver6.py")

# %%
print("1) import python file ... OK")

# %% [markdown]
# ## 2. Codes

# %%
import os

# %%
USERNAME = os.environ["USERNAME"]
PASSWORD = os.environ["PASSWORD"]
FILENAME = os.environ["FILENAME"]

# %%
print("1) USERNAME: ", USERNAME)
print("2) PASSWORD: ", PASSWORD)
print("3) FILENAME: ", FILENAME)

# %%
wslib.download_file(FILENAME, FILENAME)

# %%
print("2) import csv file ... OK")

# %%
from gov_map_ver6 import MapTerm_JOB

inst3 = MapTerm_JOB(USERNAME, PASSWORD, FILENAME)

# %%
inst3.map_terms_to_asset(FILENAME)

# %%
print("3) run JOB ... OK")
